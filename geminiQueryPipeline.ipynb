# %%
list(client.batches.list())
# Out:
# [BatchJob(
#    create_time=datetime.datetime(2026, 2, 5, 8, 5, 1, 109024, tzinfo=TzInfo(UTC)),
#    display_name='batch-paired-polite-hedge-and-categorical',
#    model='models/gemini-3-flash-preview',
#    name='batches/e8uw77lse9dlhluzx5w3uqq3jwvvfn694i1g',
#    state=<JobState.JOB_STATE_PENDING: 'JOB_STATE_PENDING'>,
#    update_time=datetime.datetime(2026, 2, 5, 8, 5, 1, 109024, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 5, 8, 4, 14, 276352, tzinfo=TzInfo(UTC)),
#    display_name='batch-paired-hedge-and-categorical',
#    model='models/gemini-3-flash-preview',
#    name='batches/wi2gbzdhu1telhq5n2xj2fwvkn7v6ivhxip1',
#    state=<JobState.JOB_STATE_PENDING: 'JOB_STATE_PENDING'>,
#    update_time=datetime.datetime(2026, 2, 5, 8, 4, 14, 276352, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 5, 8, 1, 56, 768566, tzinfo=TzInfo(UTC)),
#    display_name='batch-paired-hedge-and-categorical',
#    model='models/gemini-3-flash-preview',
#    name='batches/gied1g0npxsvmxqzdrjx46dsp4m9ghrsvccm',
#    state=<JobState.JOB_STATE_PENDING: 'JOB_STATE_PENDING'>,
#    update_time=datetime.datetime(2026, 2, 5, 8, 1, 56, 768566, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 5, 8, 0, 42, 774918, tzinfo=TzInfo(UTC)),
#    display_name='hedged-polite-and-categorical',
#    model='models/gemini-3-flash-preview',
#    name='batches/ci6om54fa3mljyqe7w7iexc0jybx0odfdipj',
#    state=<JobState.JOB_STATE_PENDING: 'JOB_STATE_PENDING'>,
#    update_time=datetime.datetime(2026, 2, 5, 8, 0, 42, 774918, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 5, 7, 58, 22, 201208, tzinfo=TzInfo(UTC)),
#    display_name='hedged-and-categorical',
#    model='models/gemini-3-flash-preview',
#    name='batches/pqmuie46ne24ej859iwwpxmf088fzjkunogr',
#    state=<JobState.JOB_STATE_RUNNING: 'JOB_STATE_RUNNING'>,
#    update_time=datetime.datetime(2026, 2, 5, 8, 4, 32, 411254, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 5, 7, 38, 48, 952463, tzinfo=TzInfo(UTC)),
#    display_name='hedged-polite-and-categorical',
#    end_time=datetime.datetime(2026, 2, 5, 7, 54, 0, 847311, tzinfo=TzInfo(UTC)),
#    model='models/gemini-3-flash-preview',
#    name='batches/3lxu8mb1xv4sbo6rcjpf7j90crewc8yp6qp9',
#    state=<JobState.JOB_STATE_CANCELLED: 'JOB_STATE_CANCELLED'>,
#    update_time=datetime.datetime(2026, 2, 5, 7, 54, 0, 847311, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 5, 7, 18, 15, 700680, tzinfo=TzInfo(UTC)),
#    display_name='batch-paired-hedge-and-categorical',
#    end_time=datetime.datetime(2026, 2, 5, 7, 54, 42, 147191, tzinfo=TzInfo(UTC)),
#    model='models/gemini-3-flash-preview',
#    name='batches/xqk6un6c8ytlt2d6sa74jin8rribnnyun348',
#    state=<JobState.JOB_STATE_CANCELLED: 'JOB_STATE_CANCELLED'>,
#    update_time=datetime.datetime(2026, 2, 5, 7, 54, 42, 147191, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 5, 6, 8, 13, 853797, tzinfo=TzInfo(UTC)),
#    dest=BatchJobDestination(
#      file_name='files/batch-ynou9no4f0pcm2bpz8jasyo4x2l6bctohsma'
#    ),
#    display_name='hedged-and-categorical',
#    end_time=datetime.datetime(2026, 2, 5, 6, 32, 49, 408069, tzinfo=TzInfo(UTC)),
#    model='models/gemini-3-flash-preview',
#    name='batches/ynou9no4f0pcm2bpz8jasyo4x2l6bctohsma',
#    state=<JobState.JOB_STATE_SUCCEEDED: 'JOB_STATE_SUCCEEDED'>,
#    update_time=datetime.datetime(2026, 2, 5, 6, 32, 49, 408069, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 5, 6, 8, 5, 961061, tzinfo=TzInfo(UTC)),
#    display_name='hedged-and-categorical',
#    end_time=datetime.datetime(2026, 2, 5, 6, 10, 33, 495914, tzinfo=TzInfo(UTC)),
#    model='models/gemini-3-flash-preview',
#    name='batches/oqteh3rknqpaq3xuiz6n43ivlv41eu026c8w',
#    state=<JobState.JOB_STATE_CANCELLED: 'JOB_STATE_CANCELLED'>,
#    update_time=datetime.datetime(2026, 2, 5, 6, 10, 33, 495914, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 5, 5, 20, 2, 193789, tzinfo=TzInfo(UTC)),
#    display_name='hedged-and-categorical',
#    end_time=datetime.datetime(2026, 2, 5, 6, 1, 32, 70775, tzinfo=TzInfo(UTC)),
#    model='models/gemini-3-flash-preview',
#    name='batches/i8pi3gqzj2mne7jhkcf2leetwrqe3w4d86d4',
#    state=<JobState.JOB_STATE_CANCELLED: 'JOB_STATE_CANCELLED'>,
#    update_time=datetime.datetime(2026, 2, 5, 6, 1, 32, 70775, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 4, 17, 20, 24, 383347, tzinfo=TzInfo(UTC)),
#    dest=BatchJobDestination(
#      file_name='files/batch-zb503e3s3bdj0n126jxsv90v74dy4ym8tsbz'
#    ),
#    display_name='comparison-categorical-predicate',
#    end_time=datetime.datetime(2026, 2, 4, 18, 59, 32, 779179, tzinfo=TzInfo(UTC)),
#    model='models/gemini-3-flash-preview',
#    name='batches/zb503e3s3bdj0n126jxsv90v74dy4ym8tsbz',
#    state=<JobState.JOB_STATE_SUCCEEDED: 'JOB_STATE_SUCCEEDED'>,
#    update_time=datetime.datetime(2026, 2, 4, 18, 59, 32, 779179, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 4, 17, 2, 2, 825411, tzinfo=TzInfo(UTC)),
#    dest=BatchJobDestination(
#      file_name='files/batch-heyp2vljomt4gvzvkcgvt2f1t40yzc6915iw'
#    ),
#    display_name='files/ozhdg2qwvjr2',
#    end_time=datetime.datetime(2026, 2, 4, 18, 55, 35, 45966, tzinfo=TzInfo(UTC)),
#    model='models/gemini-3-flash-preview',
#    name='batches/heyp2vljomt4gvzvkcgvt2f1t40yzc6915iw',
#    state=<JobState.JOB_STATE_SUCCEEDED: 'JOB_STATE_SUCCEEDED'>,
#    update_time=datetime.datetime(2026, 2, 4, 18, 55, 35, 45966, tzinfo=TzInfo(UTC))
#  ),
#  BatchJob(
#    create_time=datetime.datetime(2026, 2, 4, 5, 38, 33, 707934, tzinfo=TzInfo(UTC)),
#    dest=BatchJobDestination(
#      file_name='files/batch-y7wi6gn3fvbr1kmcu829h6tspenlwdeyjgt6'
#    ),
#    display_name='file-upload-job-1',
#    end_time=datetime.datetime(2026, 2, 4, 5, 41, 57, 832510, tzinfo=TzInfo(UTC)),
#    model='models/gemini-3-flash-preview',
#    name='batches/y7wi6gn3fvbr1kmcu829h6tspenlwdeyjgt6',
#    state=<JobState.JOB_STATE_SUCCEEDED: 'JOB_STATE_SUCCEEDED'>,
#    update_time=datetime.datetime(2026, 2, 4, 5, 41, 57, 832510, tzinfo=TzInfo(UTC))
#  )]

# %%
import json
from google import genai
from google.genai import types
import os
import pandas as pd
import random
from dotenv import load_dotenv
load_dotenv()

client = genai.Client(
    api_key=os.getenv("google_api_key"),
)


predicates = ['cold', 'loud', 'messy', 'long']
scales = {
    'cold':["Much colder","Somewhat colder","About the same","Somewhat warmer","Much warmer"],
    'loud':["Much louder","Somewhat louder","About the same","Somewhat quieter","Much quieter"],
    'messy':["Much messier","Somewhat messier","About the same","Somewhat tidier","Much tidier"],
    'long':["Much longer","Somewhat longer","About the same","Somewhat shorter","Much shorter"],
}
df = pd.read_csv('PolitenessScenario.csv')[['baseline', 'c1', 'hedged_baseline','predicate question','politeness question']] # change this to predicate question for the how cold? questions
modifiers = ['slightly','kind of','quite', 'very', 'extremely']

# %%
    
def create_prompt(scenario,predicate, question, modifier):
    speaker = question.split(' ')[3]
    start_pos = scenario.find('"')
    end_pos = scenario.rfind('"')
    combined_prompt = f"""
Please read this scenario and answer the question afterwards:
Scenario:
{scenario.replace('[modifier] ', '')}

Question: If {speaker} had said "{scenario[start_pos + 1:end_pos].replace('[modifier]', modifier)}" (adding "{modifier}"), does this mean they are actually feeling:
(A) {scales[predicate][0]}
(B) {scales[predicate][1]}
(C) {scales[predicate][2]}
(D) {scales[predicate][3]}
(E) {scales[predicate][4]}

Please output your answer as a json format like this:
{{"scenario_answer": "<your_choice>"}}

Do not output anything else.
    """
    return combined_prompt

# %%
def create_politeness_prompt(scenario,predicate,question, modifier):
    speaker = question.split(' ')[3]
    start_pos = scenario.find('"')
    end_pos = scenario.rfind('"')
    combined_prompt = f"""
Please read this scenario and answer the question afterwards:
Scenario:
{scenario.replace('[modifier] ', '')}

Question: If {speaker} had said "{scenario[start_pos + 1:end_pos].replace('[modifier]', modifier)}" (adding "{modifier}"),would it be:
(A) Much less polite
(B) Somewhat less polite
(C) About the same politeness
(D) Somewhat more polite
(E) Much more polite

Please output your answer as a json format like this:
{{"scenario_answer": "<your_choice>"}}

Do not output anything else.
    """
    return combined_prompt

# %%
def create_combined_prompt(scenario1,scenario2,predicate, question, modifier):
    # create combined prompt with the **4** scenarios in random order
    # generate in random order, 4 combinations of modified and unmodified scenarios with c1 or baseline
    swap = random.choice([True, False])
    scenarios = ["", ""]
    if not swap:
        scenarios[0] = scenario1
        scenarios[1] = scenario2
    else:
        scenarios[0] = scenario2
        scenarios[1] = scenario1
    speaker = question.split(' ')[3]
    start_pos = scenario1.find('"')
    end_pos = scenario1.rfind('"')
    combined_prompt = f"""
Please read these two scenarios:
Scenario 1:
{scenarios[0].replace('[modifier] ', '')}

Scenario 2:
{scenarios[1].replace('[modifier] ', '')}

If {speaker} had said "{scenario1[start_pos + 1:end_pos].replace('[modifier]', modifier)}" (adding "{modifier}"), does this mean they are actually feeling:
(A) {scales[predicate][0]}
(B) {scales[predicate][1]}
(C) {scales[predicate][2]}
(D) {scales[predicate][3]}
(E) {scales[predicate][4]}

Please only output your answer as a json format like this:
{{"scenario_1_answer": "<your_choice_for_scenario_1>", "scenario_2_answer": "<your_choice_for_scenario_2>"}}

Do not output anything else.
    """
    return combined_prompt,swap

# %%
def create_combined_polite_prompt(scenario1,scenario2,predicate, question, modifier):
    # create combined prompt with the **4** scenarios in random order
    # generate in random order, 4 combinations of modified and unmodified scenarios with c1 or baseline
    swap = random.choice([True, False])
    scenarios = ["", ""]
    if not swap:
        scenarios[0] = scenario1
        scenarios[1] = scenario2
    else:
        scenarios[0] = scenario2
        scenarios[1] = scenario1
    speaker = question.split(' ')[3]
    start_pos = scenario1.find('"')
    end_pos = scenario1.rfind('"')
    combined_prompt = f"""
Please read these two scenarios:
Scenario 1:
{scenarios[0].replace('[modifier] ', '')}

Scenario 2:
{scenarios[1].replace('[modifier] ', '')}

If {speaker} had said "{scenario1[start_pos + 1:end_pos].replace('[modifier]', modifier)}" (adding "{modifier}"),would it be:
(A) Much less polite
(B) Somewhat less polite
(C) About the same politeness
(D) Somewhat more polite
(E) Much more polite

Please provide your choice for each of the two scenarios. Output your answer as a json format like this:
{{"scenario_1_answer": "<your_choice_for_scenario_1>", "scenario_2_answer": "<your_choice_for_scenario_2>"}}

Do not output anything else.
    """
    return combined_prompt,swap

# %%
requests = []
with open("batch-hedge-and-categorical.jsonl", "w") as f:
    for modifier in modifiers:
        for index, row in df.iterrows():
            for attempt in range(3):
                baseline = row['baseline']
                hedged_baseline = row['hedged_baseline']
                question = row['predicate question']     
                scenario_values = ["",""]
                prompt = create_prompt(baseline,predicates[int(index/5)],question,modifier)
                requests.append({"key": f"request-{len(requests) + 1}", "request": {"contents": [{"parts": [{"text": prompt}]}]}})
                prompt = create_prompt(hedged_baseline,predicates[int(index/5)],question,modifier)
                requests.append({"key": f"request-hedge-{len(requests) + 1}", "request": {"contents": [{"parts": [{"text": prompt}]}]}})
                print(prompt)
    for req in requests:
        f.write(json.dumps(req) + "\n")

uploaded_file = client.files.upload(
    file='batch-hedge-and-categorical.jsonl',
    config=types.UploadFileConfig(display_name='batch-hedge-and-categorical', mime_type='jsonl')
)
input_file = uploaded_file.name
file_batch_job = client.batches.create(
    model="gemini-3-flash-preview",
    src=input_file,
    config={
        'display_name': "hedged-and-categorical",
    },
)

print(f"Created batch job: {file_batch_job.name}")
# Out:
# Please read this scenario and answer the question afterwards:
# Scenario:
# In their office, Terry tells his coworker, "I’m sorry but the room is cold," and asks them to raise the temperature.
#
# Question: If Terry had said "I’m sorry but the room is slightly cold," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In their office, Terry tells his coworker, "I’m sorry but the room is cold," and asks them to raise the temperature.
#
# Question: If Terry had said "I’m sorry but the room is slightly cold," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In their office, Terry tells his coworker, "I’m sorry but the room is cold," and asks them to raise the temperature.
#
# Question: If Terry had said "I’m sorry but the room is slightly cold," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a classroom, Anni says to her homeroom teacher, "Excuse me but the air conditioning is cold" and asks her teacher to change the settings.
#
# Question: If Anni had said "Excuse me but the air conditioning is slightly cold" (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a classroom, Anni says to her homeroom teacher, "Excuse me but the air conditioning is cold" and asks her teacher to change the settings.
#
# Question: If Anni had said "Excuse me but the air conditioning is slightly cold" (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a classroom, Anni says to her homeroom teacher, "Excuse me but the air conditioning is cold" and asks her teacher to change the settings.
#
# Question: If Anni had said "Excuse me but the air conditioning is slightly cold" (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a taxi, Dan tells the driver, "Excuse me but it's cold," and asks them to turn down the air conditioning.
#
# Question: If Dan had said "Excuse me but it's slightly cold," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a taxi, Dan tells the driver, "Excuse me but it's cold," and asks them to turn down the air conditioning.
#
# Question: If Dan had said "Excuse me but it's slightly cold," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a taxi, Dan tells the driver, "Excuse me but it's cold," and asks them to turn down the air conditioning.
#
# Question: If Dan had said "Excuse me but it's slightly cold," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# At a restaurant, Melissa tells the staff, "Excuse me but the air conditioning is cold," and asks him to change the settings.
#
# Question: If Melissa had said "Excuse me but the air conditioning is slightly cold," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# At a restaurant, Melissa tells the staff, "Excuse me but the air conditioning is cold," and asks him to change the settings.
#
# Question: If Melissa had said "Excuse me but the air conditioning is slightly cold," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# At a restaurant, Melissa tells the staff, "Excuse me but the air conditioning is cold," and asks him to change the settings.
#
# Question: If Melissa had said "Excuse me but the air conditioning is slightly cold," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Dylan is attending a game night at Mary's house. Dylan tells Mary, "I’m sorry but it's cold here," and asks her to raise the temperature.
#
# Question: If Dylan had said "I’m sorry but it's slightly cold here," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Dylan is attending a game night at Mary's house. Dylan tells Mary, "I’m sorry but it's cold here," and asks her to raise the temperature.
#
# Question: If Dylan had said "I’m sorry but it's slightly cold here," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Dylan is attending a game night at Mary's house. Dylan tells Mary, "I’m sorry but it's cold here," and asks her to raise the temperature.
#
# Question: If Dylan had said "I’m sorry but it's slightly cold here," (adding "slightly"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# A coworker started her lunch break early is talking on the phone with a friend next to Lisa. Lisa tells the coworker, "I’m sorry but your voice is loud," and asks them to be quieter.
#
# Question: If Lisa had said "I’m sorry but your voice is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# A coworker started her lunch break early is talking on the phone with a friend next to Lisa. Lisa tells the coworker, "I’m sorry but your voice is loud," and asks them to be quieter.
#
# Question: If Lisa had said "I’m sorry but your voice is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# A coworker started her lunch break early is talking on the phone with a friend next to Lisa. Lisa tells the coworker, "I’m sorry but your voice is loud," and asks them to be quieter.
#
# Question: If Lisa had said "I’m sorry but your voice is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Amy is playing games in her room, and her roommate Jake is practicing piano in the living room. Amy tells Jake, "I’m sorry but the sound is loud," and asks him to turn down the volume.
#
# Question: If Amy had said "I’m sorry but the sound is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Amy is playing games in her room, and her roommate Jake is practicing piano in the living room. Amy tells Jake, "I’m sorry but the sound is loud," and asks him to turn down the volume.
#
# Question: If Amy had said "I’m sorry but the sound is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Amy is playing games in her room, and her roommate Jake is practicing piano in the living room. Amy tells Jake, "I’m sorry but the sound is loud," and asks him to turn down the volume.
#
# Question: If Amy had said "I’m sorry but the sound is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Sarah is at a restaurant with a friend. She tells the staff, "Excuse me but the volume is loud," and asks them to turn it down.
#
# Question: If Sarah had said "Excuse me but the volume is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Sarah is at a restaurant with a friend. She tells the staff, "Excuse me but the volume is loud," and asks them to turn it down.
#
# Question: If Sarah had said "Excuse me but the volume is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Sarah is at a restaurant with a friend. She tells the staff, "Excuse me but the volume is loud," and asks them to turn it down.
#
# Question: If Sarah had said "Excuse me but the volume is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Claire is studying for an exam, but her brother is gaming in the living room. Claire says, "I’m sorry but the sound is loud," and asks him to be quieter.
#
# Question: If Claire had said "I’m sorry but the sound is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Claire is studying for an exam, but her brother is gaming in the living room. Claire says, "I’m sorry but the sound is loud," and asks him to be quieter.
#
# Question: If Claire had said "I’m sorry but the sound is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Claire is studying for an exam, but her brother is gaming in the living room. Claire says, "I’m sorry but the sound is loud," and asks him to be quieter.
#
# Question: If Claire had said "I’m sorry but the sound is slightly loud," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# During class, students sitting near Alex are talking loudly. Alex tells them, "Excuse me but your voices are loud and disrupting the class," and asks them to lower their voices.
#
#
# Question: If Alex had said "Excuse me but your voices are slightly loud and disrupting the class," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# During class, students sitting near Alex are talking loudly. Alex tells them, "Excuse me but your voices are loud and disrupting the class," and asks them to lower their voices.
#
#
# Question: If Alex had said "Excuse me but your voices are slightly loud and disrupting the class," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# During class, students sitting near Alex are talking loudly. Alex tells them, "Excuse me but your voices are loud and disrupting the class," and asks them to lower their voices.
#
#
# Question: If Alex had said "Excuse me but your voices are slightly loud and disrupting the class," (adding "slightly"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Tom and his housemate Jordan have invited their friends over. Tom tells Jordan, "I’m sorry but the sofa is messy," and asks him to clean his things up before the guests arrive.
#
# Question: If Tom had said "I’m sorry but the sofa is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Tom and his housemate Jordan have invited their friends over. Tom tells Jordan, "I’m sorry but the sofa is messy," and asks him to clean his things up before the guests arrive.
#
# Question: If Tom had said "I’m sorry but the sofa is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Tom and his housemate Jordan have invited their friends over. Tom tells Jordan, "I’m sorry but the sofa is messy," and asks him to clean his things up before the guests arrive.
#
# Question: If Tom had said "I’m sorry but the sofa is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Emma is at Chloe's apartment to work on a class assignment together. Seeing notebooks and candy wrappers on the desk, Emma says, "I’m sorry but this room is messy," and they clean up together before starting work.
#
# Question: If Emma had said "I’m sorry but this room is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Emma is at Chloe's apartment to work on a class assignment together. Seeing notebooks and candy wrappers on the desk, Emma says, "I’m sorry but this room is messy," and they clean up together before starting work.
#
# Question: If Emma had said "I’m sorry but this room is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Emma is at Chloe's apartment to work on a class assignment together. Seeing notebooks and candy wrappers on the desk, Emma says, "I’m sorry but this room is messy," and they clean up together before starting work.
#
# Question: If Emma had said "I’m sorry but this room is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Leo has come to Noah's apartment to study. Leo says, "I’m sorry but this desk is messy," and asks him to organize it before they begin.
#
# Question: If Leo had said "I’m sorry but this desk is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Leo has come to Noah's apartment to study. Leo says, "I’m sorry but this desk is messy," and asks him to organize it before they begin.
#
# Question: If Leo had said "I’m sorry but this desk is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Leo has come to Noah's apartment to study. Leo says, "I’m sorry but this desk is messy," and asks him to organize it before they begin.
#
# Question: If Leo had said "I’m sorry but this desk is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Rachel picks up Sophie to go to a concert together. Seeing trash on the floor, Sophie says, "I’m sorry but the car is messy," and they clean up together before leaving.
#
# Question: If Sophie had said "I’m sorry but the car is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Rachel picks up Sophie to go to a concert together. Seeing trash on the floor, Sophie says, "I’m sorry but the car is messy," and they clean up together before leaving.
#
# Question: If Sophie had said "I’m sorry but the car is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Rachel picks up Sophie to go to a concert together. Seeing trash on the floor, Sophie says, "I’m sorry but the car is messy," and they clean up together before leaving.
#
# Question: If Sophie had said "I’m sorry but the car is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Alex's desk is overflowing with documents. Seeing this, Liam says, "I’m sorry but your desk is messy," and asks him to clean it up before Liam's client arrives.
#
# Question: If Liam had said "I’m sorry but your desk is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Alex's desk is overflowing with documents. Seeing this, Liam says, "I’m sorry but your desk is messy," and asks him to clean it up before Liam's client arrives.
#
# Question: If Liam had said "I’m sorry but your desk is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Alex's desk is overflowing with documents. Seeing this, Liam says, "I’m sorry but your desk is messy," and asks him to clean it up before Liam's client arrives.
#
# Question: If Liam had said "I’m sorry but your desk is slightly messy," (adding "slightly"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# James is talking to a coworker about this week's work meeting. James says to the coworker, "I’m sorry but the report is long" and suggests summarizing it more concisely.
#
# Question: If James had said "I’m sorry but the report is slightly long" (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# James is talking to a coworker about this week's work meeting. James says to the coworker, "I’m sorry but the report is long" and suggests summarizing it more concisely.
#
# Question: If James had said "I’m sorry but the report is slightly long" (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# James is talking to a coworker about this week's work meeting. James says to the coworker, "I’m sorry but the report is long" and suggests summarizing it more concisely.
#
# Question: If James had said "I’m sorry but the report is slightly long" (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Bill's gives a practive presentation in class. Afterwards, Anna says to Bill "I'm sorry but the introduction was long and hard to follow" and suggests him to be careful of timing in the actual presentation.
#
# Question: If Anna had said "I'm sorry but the introduction was slightly long and hard to follow" (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Bill's gives a practive presentation in class. Afterwards, Anna says to Bill "I'm sorry but the introduction was long and hard to follow" and suggests him to be careful of timing in the actual presentation.
#
# Question: If Anna had said "I'm sorry but the introduction was slightly long and hard to follow" (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Bill's gives a practive presentation in class. Afterwards, Anna says to Bill "I'm sorry but the introduction was long and hard to follow" and suggests him to be careful of timing in the actual presentation.
#
# Question: If Anna had said "I'm sorry but the introduction was slightly long and hard to follow" (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Jillian consults Dylan to review the meeting agenda she created. Dylan notices that there are too many items for the allotted time and says, "I’m sorry but this agenda is long," and suggests cutting out some topics.
#
#
# Question: If Dylan had said "I’m sorry but this agenda is slightly long," (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Jillian consults Dylan to review the meeting agenda she created. Dylan notices that there are too many items for the allotted time and says, "I’m sorry but this agenda is long," and suggests cutting out some topics.
#
#
# Question: If Dylan had said "I’m sorry but this agenda is slightly long," (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Jillian consults Dylan to review the meeting agenda she created. Dylan notices that there are too many items for the allotted time and says, "I’m sorry but this agenda is long," and suggests cutting out some topics.
#
#
# Question: If Dylan had said "I’m sorry but this agenda is slightly long," (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Maya asks her coworker Peter to check a draft email to send to a client. Peter says, "I’m sorry but this email is long," and suggests removing details to make it more concise.
#
#
# Question: If Peter had said "I’m sorry but this email is slightly long," (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Maya asks her coworker Peter to check a draft email to send to a client. Peter says, "I’m sorry but this email is long," and suggests removing details to make it more concise.
#
#
# Question: If Peter had said "I’m sorry but this email is slightly long," (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Maya asks her coworker Peter to check a draft email to send to a client. Peter says, "I’m sorry but this email is long," and suggests removing details to make it more concise.
#
#
# Question: If Peter had said "I’m sorry but this email is slightly long," (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Liam is reviewing a report Sofia prepared for her boss at her request. After finishing reading, he says, "I’m sorry but this report is long," and suggests shortening some parts to make it more concise.
#
# Question: If Liam had said "I’m sorry but this report is slightly long," (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Liam is reviewing a report Sofia prepared for her boss at her request. After finishing reading, he says, "I’m sorry but this report is long," and suggests shortening some parts to make it more concise.
#
# Question: If Liam had said "I’m sorry but this report is slightly long," (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Liam is reviewing a report Sofia prepared for her boss at her request. After finishing reading, he says, "I’m sorry but this report is long," and suggests shortening some parts to make it more concise.
#
# Question: If Liam had said "I’m sorry but this report is slightly long," (adding "slightly"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In their office, Terry tells his coworker, "I’m sorry but the room is cold," and asks them to raise the temperature.
#
# Question: If Terry had said "I’m sorry but the room is kind of cold," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In their office, Terry tells his coworker, "I’m sorry but the room is cold," and asks them to raise the temperature.
#
# Question: If Terry had said "I’m sorry but the room is kind of cold," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In their office, Terry tells his coworker, "I’m sorry but the room is cold," and asks them to raise the temperature.
#
# Question: If Terry had said "I’m sorry but the room is kind of cold," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a classroom, Anni says to her homeroom teacher, "Excuse me but the air conditioning is cold" and asks her teacher to change the settings.
#
# Question: If Anni had said "Excuse me but the air conditioning is kind of cold" (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a classroom, Anni says to her homeroom teacher, "Excuse me but the air conditioning is cold" and asks her teacher to change the settings.
#
# Question: If Anni had said "Excuse me but the air conditioning is kind of cold" (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a classroom, Anni says to her homeroom teacher, "Excuse me but the air conditioning is cold" and asks her teacher to change the settings.
#
# Question: If Anni had said "Excuse me but the air conditioning is kind of cold" (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a taxi, Dan tells the driver, "Excuse me but it's cold," and asks them to turn down the air conditioning.
#
# Question: If Dan had said "Excuse me but it's kind of cold," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a taxi, Dan tells the driver, "Excuse me but it's cold," and asks them to turn down the air conditioning.
#
# Question: If Dan had said "Excuse me but it's kind of cold," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# In a taxi, Dan tells the driver, "Excuse me but it's cold," and asks them to turn down the air conditioning.
#
# Question: If Dan had said "Excuse me but it's kind of cold," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# At a restaurant, Melissa tells the staff, "Excuse me but the air conditioning is cold," and asks him to change the settings.
#
# Question: If Melissa had said "Excuse me but the air conditioning is kind of cold," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# At a restaurant, Melissa tells the staff, "Excuse me but the air conditioning is cold," and asks him to change the settings.
#
# Question: If Melissa had said "Excuse me but the air conditioning is kind of cold," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# At a restaurant, Melissa tells the staff, "Excuse me but the air conditioning is cold," and asks him to change the settings.
#
# Question: If Melissa had said "Excuse me but the air conditioning is kind of cold," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Dylan is attending a game night at Mary's house. Dylan tells Mary, "I’m sorry but it's cold here," and asks her to raise the temperature.
#
# Question: If Dylan had said "I’m sorry but it's kind of cold here," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Dylan is attending a game night at Mary's house. Dylan tells Mary, "I’m sorry but it's cold here," and asks her to raise the temperature.
#
# Question: If Dylan had said "I’m sorry but it's kind of cold here," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Dylan is attending a game night at Mary's house. Dylan tells Mary, "I’m sorry but it's cold here," and asks her to raise the temperature.
#
# Question: If Dylan had said "I’m sorry but it's kind of cold here," (adding "kind of"), does this mean they are actually feeling:
# (A) Much colder
# (B) Somewhat colder
# (C) About the same
# (D) Somewhat warmer
# (E) Much warmer
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# A coworker started her lunch break early is talking on the phone with a friend next to Lisa. Lisa tells the coworker, "I’m sorry but your voice is loud," and asks them to be quieter.
#
# Question: If Lisa had said "I’m sorry but your voice is kind of loud," (adding "kind of"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# A coworker started her lunch break early is talking on the phone with a friend next to Lisa. Lisa tells the coworker, "I’m sorry but your voice is loud," and asks them to be quieter.
#
# Question: If Lisa had said "I’m sorry but your voice is kind of loud," (adding "kind of"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# A coworker started her lunch break early is talking on the phone with a friend next to Lisa. Lisa tells the coworker, "I’m sorry but your voice is loud," and asks them to be quieter.
#
# Question: If Lisa had said "I’m sorry but your voice is kind of loud," (adding "kind of"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Amy is playing games in her room, and her roommate Jake is practicing piano in the living room. Amy tells Jake, "I’m sorry but the sound is loud," and asks him to turn down the volume.
#
# Question: If Amy had said "I’m sorry but the sound is kind of loud," (adding "kind of"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Amy is playing games in her room, and her roommate Jake is practicing piano in the living room. Amy tells Jake, "I’m sorry but the sound is loud," and asks him to turn down the volume.
#
# Question: If Amy had said "I’m sorry but the sound is kind of loud," (adding "kind of"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Amy is playing games in her room, and her roommate Jake is practicing piano in the living room. Amy tells Jake, "I’m sorry but the sound is loud," and asks him to turn down the volume.
#
# Question: If Amy had said "I’m sorry but the sound is kind of loud," (adding "kind of"), does this mean they are actually feeling:
# (A) Much louder
# (B) Somewhat louder
# (C) About the same
# (D) Somewhat quieter
# (E) Much quieter
#
# ...
#
# Question: If Emma had said "I’m sorry but this room is extremely messy," (adding "extremely"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Emma is at Chloe's apartment to work on a class assignment together. Seeing notebooks and candy wrappers on the desk, Emma says, "I’m sorry but this room is messy," and they clean up together before starting work.
#
# Question: If Emma had said "I’m sorry but this room is extremely messy," (adding "extremely"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Leo has come to Noah's apartment to study. Leo says, "I’m sorry but this desk is messy," and asks him to organize it before they begin.
#
# Question: If Leo had said "I’m sorry but this desk is extremely messy," (adding "extremely"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Leo has come to Noah's apartment to study. Leo says, "I’m sorry but this desk is messy," and asks him to organize it before they begin.
#
# Question: If Leo had said "I’m sorry but this desk is extremely messy," (adding "extremely"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Leo has come to Noah's apartment to study. Leo says, "I’m sorry but this desk is messy," and asks him to organize it before they begin.
#
# Question: If Leo had said "I’m sorry but this desk is extremely messy," (adding "extremely"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Rachel picks up Sophie to go to a concert together. Seeing trash on the floor, Sophie says, "I’m sorry but the car is messy," and they clean up together before leaving.
#
# Question: If Sophie had said "I’m sorry but the car is extremely messy," (adding "extremely"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Rachel picks up Sophie to go to a concert together. Seeing trash on the floor, Sophie says, "I’m sorry but the car is messy," and they clean up together before leaving.
#
# Question: If Sophie had said "I’m sorry but the car is extremely messy," (adding "extremely"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Rachel picks up Sophie to go to a concert together. Seeing trash on the floor, Sophie says, "I’m sorry but the car is messy," and they clean up together before leaving.
#
# Question: If Sophie had said "I’m sorry but the car is extremely messy," (adding "extremely"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Alex's desk is overflowing with documents. Seeing this, Liam says, "I’m sorry but your desk is messy," and asks him to clean it up before Liam's client arrives.
#
# Question: If Liam had said "I’m sorry but your desk is extremely messy," (adding "extremely"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Alex's desk is overflowing with documents. Seeing this, Liam says, "I’m sorry but your desk is messy," and asks him to clean it up before Liam's client arrives.
#
# Question: If Liam had said "I’m sorry but your desk is extremely messy," (adding "extremely"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Alex's desk is overflowing with documents. Seeing this, Liam says, "I’m sorry but your desk is messy," and asks him to clean it up before Liam's client arrives.
#
# Question: If Liam had said "I’m sorry but your desk is extremely messy," (adding "extremely"), does this mean they are actually feeling:
# (A) Much messier
# (B) Somewhat messier
# (C) About the same
# (D) Somewhat tidier
# (E) Much tidier
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# James is talking to a coworker about this week's work meeting. James says to the coworker, "I’m sorry but the report is long" and suggests summarizing it more concisely.
#
# Question: If James had said "I’m sorry but the report is extremely long" (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# James is talking to a coworker about this week's work meeting. James says to the coworker, "I’m sorry but the report is long" and suggests summarizing it more concisely.
#
# Question: If James had said "I’m sorry but the report is extremely long" (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# James is talking to a coworker about this week's work meeting. James says to the coworker, "I’m sorry but the report is long" and suggests summarizing it more concisely.
#
# Question: If James had said "I’m sorry but the report is extremely long" (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Bill's gives a practive presentation in class. Afterwards, Anna says to Bill "I'm sorry but the introduction was long and hard to follow" and suggests him to be careful of timing in the actual presentation.
#
# Question: If Anna had said "I'm sorry but the introduction was extremely long and hard to follow" (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Bill's gives a practive presentation in class. Afterwards, Anna says to Bill "I'm sorry but the introduction was long and hard to follow" and suggests him to be careful of timing in the actual presentation.
#
# Question: If Anna had said "I'm sorry but the introduction was extremely long and hard to follow" (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Bill's gives a practive presentation in class. Afterwards, Anna says to Bill "I'm sorry but the introduction was long and hard to follow" and suggests him to be careful of timing in the actual presentation.
#
# Question: If Anna had said "I'm sorry but the introduction was extremely long and hard to follow" (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Jillian consults Dylan to review the meeting agenda she created. Dylan notices that there are too many items for the allotted time and says, "I’m sorry but this agenda is long," and suggests cutting out some topics.
#
#
# Question: If Dylan had said "I’m sorry but this agenda is extremely long," (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Jillian consults Dylan to review the meeting agenda she created. Dylan notices that there are too many items for the allotted time and says, "I’m sorry but this agenda is long," and suggests cutting out some topics.
#
#
# Question: If Dylan had said "I’m sorry but this agenda is extremely long," (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Jillian consults Dylan to review the meeting agenda she created. Dylan notices that there are too many items for the allotted time and says, "I’m sorry but this agenda is long," and suggests cutting out some topics.
#
#
# Question: If Dylan had said "I’m sorry but this agenda is extremely long," (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Maya asks her coworker Peter to check a draft email to send to a client. Peter says, "I’m sorry but this email is long," and suggests removing details to make it more concise.
#
#
# Question: If Peter had said "I’m sorry but this email is extremely long," (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Maya asks her coworker Peter to check a draft email to send to a client. Peter says, "I’m sorry but this email is long," and suggests removing details to make it more concise.
#
#
# Question: If Peter had said "I’m sorry but this email is extremely long," (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Maya asks her coworker Peter to check a draft email to send to a client. Peter says, "I’m sorry but this email is long," and suggests removing details to make it more concise.
#
#
# Question: If Peter had said "I’m sorry but this email is extremely long," (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Liam is reviewing a report Sofia prepared for her boss at her request. After finishing reading, he says, "I’m sorry but this report is long," and suggests shortening some parts to make it more concise.
#
# Question: If Liam had said "I’m sorry but this report is extremely long," (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Liam is reviewing a report Sofia prepared for her boss at her request. After finishing reading, he says, "I’m sorry but this report is long," and suggests shortening some parts to make it more concise.
#
# Question: If Liam had said "I’m sorry but this report is extremely long," (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
#
# Please read this scenario and answer the question afterwards:
# Scenario:
# Liam is reviewing a report Sofia prepared for her boss at her request. After finishing reading, he says, "I’m sorry but this report is long," and suggests shortening some parts to make it more concise.
#
# Question: If Liam had said "I’m sorry but this report is extremely long," (adding "extremely"), does this mean they are actually feeling:
# (A) Much longer
# (B) Somewhat longer
# (C) About the same
# (D) Somewhat shorter
# (E) Much shorter
#
# Please output your answer as a json format like this:
# {"scenario_answer": "<your_choice>"}
#
# Do not output anything else.
#
# Created batch job: batches/pqmuie46ne24ej859iwwpxmf088fzjkunogr

# %%
requests = []
with open("batch-hedge-polite-and-categorical.jsonl", "w") as f:
    for modifier in modifiers:
        for index, row in df.iterrows():
            for attempt in range(3):
                baseline = row['baseline']
                hedged_baseline = row['hedged_baseline']   
                question = row['politeness question']   
                scenario_values = ["",""]
                prompt = create_politeness_prompt(baseline,predicates[int(index/5)],question,modifier)
                requests.append({"key": f"request-{len(requests) + 1}", "request": {"contents": [{"parts": [{"text": prompt}]}]}})
                prompt = create_politeness_prompt(hedged_baseline,predicates[int(index/5)],question,modifier)
                requests.append({"key": f"request-hedge-{len(requests) + 1}", "request": {"contents": [{"parts": [{"text": prompt}]}]}})
    for req in requests:
        f.write(json.dumps(req) + "\n")

uploaded_file = client.files.upload(
    file='batch-hedge-polite-and-categorical.jsonl',
    config=types.UploadFileConfig(display_name='batch-hedge-polite-and-categorical', mime_type='jsonl')
)
input_file = uploaded_file.name
file_batch_job = client.batches.create(
    model="gemini-3-flash-preview",
    src=input_file,
    config={
        'display_name': "hedged-polite-and-categorical",
    },
)

print(f"Created batch job: {file_batch_job.name}")
# Out:
# Created batch job: batches/ci6om54fa3mljyqe7w7iexc0jybx0odfdipj

# %%
# Create a sample JSONL file
swapped_list = []
requests = []
with open("batch-paired-hedge-and-categorical.jsonl", "w") as f:
    for modifier in modifiers:
        for index, row in df.iterrows():
            for attempt in range(3):
                baseline = row['baseline']
                hedged = row['hedged_baseline']
                question = row['predicate question']     
                scenario_values = ["",""]
                prompt , swapped = create_combined_prompt(baseline,hedged,predicates[int(index/5)],question,modifier)
                swapped_list.append(swapped)
                requests.append({"key": f"request-{len(requests) + 1}-{swapped}", "request": {"contents": [{"parts": [{"text": prompt}]}]}})
    for req in requests:
        f.write(json.dumps(req) + "\n")
with open("swapped_paired_list_feb4.json", "w") as f:
    json.dump(swapped_list, f)

uploaded_file = client.files.upload(
    file='batch-paired-hedge-and-categorical.jsonl',
    config=types.UploadFileConfig(display_name='batch-paired-hedge-and-categorical', mime_type='jsonl')
)
input_file = uploaded_file.name
print(f"Uploaded file: {uploaded_file.name}")
file_batch_job = client.batches.create(
    model="gemini-3-flash-preview",
    src=input_file,
    config={
        'display_name': "batch-paired-hedge-and-categorical",
    },
)

print(f"Created batch job: {file_batch_job.name}")
# Out:
# Uploaded file: files/gukwhhx2zig5
# Created batch job: batches/wi2gbzdhu1telhq5n2xj2fwvkn7v6ivhxip1

# %%
# Create a sample JSONL file
swapped_list = []
requests = []
with open("batch-paired-polite-hedge-and-categorical.jsonl", "w") as f:
    for modifier in modifiers:
        for index, row in df.iterrows():
            for attempt in range(3):
                question = row["politeness question"]
                baseline = row['baseline']
                hedged = row['hedged_baseline']   
                scenario_values = ["",""]
                prompt , swapped = create_combined_polite_prompt(baseline,hedged,predicates[int(index/5)],question,modifier)
                swapped_list.append(swapped)
                requests.append({"key": f"request-{len(requests) + 1}-{swapped}", "request": {"contents": [{"parts": [{"text": prompt}]}]}})
    for req in requests:
        f.write(json.dumps(req) + "\n")
with open("polite_swapped_paired_list_feb4.json", "w") as f:
    json.dump(swapped_list, f)

uploaded_file = client.files.upload(
    file='batch-paired-polite-hedge-and-categorical.jsonl',
    config=types.UploadFileConfig(display_name='batch-paired-polite-hedge-and-categorical', mime_type='jsonl')
)
input_file = uploaded_file.name
print(f"Uploaded file: {uploaded_file.name}")
file_batch_job = client.batches.create(
    model="gemini-3-flash-preview",
    src=input_file,
    config={
        'display_name': "batch-paired-polite-hedge-and-categorical",
    },
)

print(f"Created batch job: {file_batch_job.name}")
# Out:
# Uploaded file: files/g7mqxfp5br5n
# Created batch job: batches/e8uw77lse9dlhluzx5w3uqq3jwvvfn694i1g

# %%
job_name = file_batch_job.name  # (e.g. 'batches/your-batch-id')
batch_job = client.batches.get(name=job_name)

completed_states = set([
    'JOB_STATE_SUCCEEDED',
    'JOB_STATE_FAILED',
    'JOB_STATE_CANCELLED',
    'JOB_STATE_EXPIRED',
])

print(f"Polling status for job: {job_name}")
batch_job = client.batches.get(name=job_name) # Initial get
print(f"Current state: {batch_job.state.name}")
# Out:
# Polling status for job: batches/e8uw77lse9dlhluzx5w3uqq3jwvvfn694i1g
# Current state: JOB_STATE_PENDING

# %%
response_outputs = []
if batch_job.state.name == 'JOB_STATE_SUCCEEDED':
    result_file_name = batch_job.dest.file_name
    file_content = client.files.download(file=result_file_name).decode('utf-8')
    for line_num, line in enumerate(file_content.split('\n'), 1):
        line = line.strip()
        if not line:
            print("not line")
            print(line_num)
            continue
        try:
            data = json.loads(line)
            response = data['response']['candidates'][0]['content']['parts'][0]['text']
            start = response.find('{')
            end = response.rfind('}') + 1
            response = json.loads(response[start:end])
            response["scenario_answer"] = response["scenario_answer"].strip('()')
            response_outputs.append(response["scenario_answer"])
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON on line {line_num}: {e}")
            continue
else:
    print(f"Job did not succeed. Final state: {batch_job.state.name}")
    if batch_job.error:
        print(f"Error: {batch_job.error}")
list_outputs.append([modifier,question] + scenario_values)
index_num = 0
for modifier in modifiers:
    for index, row in df.iterrows():
        question = row['predicate question'] 
        choices_baseline = ""
        choices_hedged = ""
        for attempt in range(3):
            choices_baseline += response_outputs[index_num]
            choices_hedged += response_outputs[index_num+1]
            index_num+=2
        list_outputs.append([modidifier,question,choices_baseline,choices_hedged]
                
df_outputs = pd.DataFrame(list_outputs, columns=['modifier', 'question', 'baseline', 'hedge_baseline'])                
df_outputs.to_csv('hedged-and-categorical.csv', index=False)

# %%
# Store lists
list_outputs = [
    ['mod1', 'q1', ['A', 'B', 'C'], ['D', 'E']],
    ['mod2', 'q2', ['F', 'G'], ['H', 'I', 'J']],
]

df = pd.DataFrame(list_outputs, columns=['modifier', 'question', 'options1', 'options2'])

# Retrieve
options = df.loc[0, 'options1']
print(options)  # ['A', 'B', 'C']
print(options[0])  # 'A'
# Out:
# ['A', 'B', 'C']
# A
